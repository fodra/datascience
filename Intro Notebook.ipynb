# %%
print("Andrew")
# Out:
# Andrew

# %%
366 * 24 * 60 * 60
# Out:
# 31622400

# %%
_ / 1e6
# Out:
# 31.6224

# %%
365 * 24 * 60 * 60
# Out:
# 31536000

# %%
_ / 1e6
# Out:
# 31.536

# %% [markdown]
# # A very interesting subject
#
# This is an explanation of a very interesting subject that is demonstrated here in my jupyter notebook.

# %%
# %matplotlib inline
from matplotlib.pyplot import plot
plot([0,1,0,1])

# %% [markdown]
# This is a graph of a vector.

# %%
# !ls
# Out:
# Intro Notebook.ipynb README.md            Week-2-Assignment
# LICENSE              Week-1-Intro-new

# %%
# !pip install matplotlib

# %%
# !head -n 1 README.md
# Out:
# # DataScience

# %%
# !tail -n 1 README.md
# Out:
# Introduction - Soccer Data Analysis

# %%
# !wc README.md
# Out:
#        9      32     203 README.md
